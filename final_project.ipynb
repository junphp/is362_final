# %% [markdown]
# ## IS362 FINAL PROJECT

# %%
from pandas import DataFrame, read_csv
import pandas as pd
import numpy as np
import html5lib
import matplotlib.pyplot as plt

# %% [markdown]
# ###### My project is an analysis of the best-selling games. I will obtain and plot the most sold platforms and producers.

# %% [markdown]
# ###### The list of platforms is loaded.

# %%
platformslist = pd.read_html('https://www.neoseeker.com/Games/platformslist.html',header=0,skiprows=[1])[0]

# %% [markdown]
# ###### CLEAR DATASET

# %%
platformslist.drop(["Abbrev","Release Year","Unnamed: 4"],axis=1)
# Out:
#                                Platform   Company
# 0                                    PC        PC
# 1                         Playstation 4       PS4
# 2                              Xbox One   XBOXONE
# 3                                 Wii U     wii-u
# 4                       Nintendo Switch    Switch
# 5                         Playstation 3       PS3
# 6                              XBOX 360   XBOX360
# 7                                   Wii       Wii
# 8                                   Mac       Mac
# 9                                 Linux     Linux
# 10                            HANDHELDS       NaN
# 11                         Nintendo 3DS       3DS
# 12                     PlayStation Vita      vita
# 13                                   DS        DS
# 14                 Playstation Portable       PSP
# 15                               MOBILE       NaN
# 16                               iPhone    iPhone
# 17                        Windows Phone        wp
# ...

# %% [markdown]
# ###### total Platform Type

# %%
platformslist["Platform"].count()
# Out:
# 40

# %% [markdown]
# ###### Import rank of best seller video game

# %%
vgrank = pd.read_csv("https://raw.githubusercontent.com/junphp/is362_final/master/vgsales.csv")

# %%
vgrank.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %% [markdown]
# ###### Best Rank Platform Count

# %%
marketrate = vgrank.groupby(['Platform']).size().sort_values(ascending=False)

# %%
marketrate
# Out:
# Platform
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# dtype: int64

# %% [markdown]
# ###### Sales totals for each platform

# %%
vgrank.groupby(['Platform'])['Global_Sales'].agg('sum').sort_values(ascending=False)
# Out:
# Platform
# PS2     1255.64
# X360     979.96
# PS3      957.84
# Wii      926.71
# DS       822.49
# PS       730.66
# GBA      318.50
# PSP      296.28
# PS4      278.10
# PC       258.82
# XB       258.26
# GB       255.45
# NES      251.07
# 3DS      247.46
# N64      218.88
# SNES     200.05
# GC       199.36
# XOne     141.06
# 2600      97.08
# WiiU      81.86
# PSV       61.93
# SAT       33.59
# GEN       28.36
# DC        15.97
# SCD        1.87
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ###### Sales total by company

# %%
vgrank.groupby(['Publisher'])['Global_Sales'].agg('sum').sort_values(ascending=False)
# Out:
# Publisher
# Nintendo                                  1786.56
# Electronic Arts                           1110.32
# Activision                                 727.46
# Sony Computer Entertainment                607.50
# Ubisoft                                    474.72
# Take-Two Interactive                       399.54
# THQ                                        340.77
# Konami Digital Entertainment               283.64
# Sega                                       272.99
# Namco Bandai Games                         254.09
# Microsoft Game Studios                     245.79
# Capcom                                     200.89
# Atari                                      157.22
# Warner Bros. Interactive Entertainment     153.89
# Square Enix                                145.18
# Disney Interactive Studios                 119.96
# Eidos Interactive                           98.98
# LucasArts                                   87.34
# Bethesda Softworks                          82.14
# ...

# %%
vgrank.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
vgrank2=pd.read_csv("https://raw.githubusercontent.com/junphp/is362_final/master/group.csv",header=None)

# %%
vgrank2.columns=["Rank","Name","Platform","Year","Genre","Publisher","NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]
vgrank2.drop(["Rank"],axis=1)
# Out:
#                                       Name  Platform  Year         Genre  \
# 0                                  Pac-Man      2600  1982        Puzzle
# 1                              Policenauts       3DO  1995     Adventure
# 2                      Pokemon X/Pokemon Y       3DS  2013  Role-Playing
# 3                          Sonic Adventure        DC  1998      Platform
# 4                    New Super Mario Bros.        DS  2006      Platform
# 5                 Pokemon Red/Pokemon Blue        GB  1996  Role-Playing
# 6            Pokemon Ruby/Pokemon Sapphire       GBA  2002  Role-Playing
# 7                  Super Smash Bros. Melee        GC  2001      Fighting
# 8                     Sonic the Hedgehog 2       GEN  1992      Platform
# 9             Sonic the Hedgehog 2 (8-bit)        GG  1992      Platform
# 10                          Super Mario 64       N64  1996      Platform
# 11                       Super Mario Bros.       NES  1985      Platform
# ...

# %%
x= vgrank2['Global_Sales'].plot(kind='bar')

# %%
plt.show()

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# #### PS2's Grand Theft Auto : San Andreas is the best-selling game.
